# %%
import sys
# append the path of the parent directory
sys.path.append("..")

# %%
import math
import os
import time


import numpy as np
np.set_printoptions(legacy='1.25')

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
import matplotlib.patches as patches

import seaborn as sns
import time
import json
import pandas as pd
from ctypes import c_int32
from itertools import product
import copy
from matplotlib.lines import Line2D

from matplotlib.patches import Patch


from tqdm import tqdm

from scipy.stats import pearsonr
from importlib import reload

import orjson
import gzip

from scipy.stats import entropy
from pympler import asizeof

from lib import sketches, visualization_utils, encoders, ploting, pacha_sketch
reload(ploting)
reload(sketches)
reload(visualization_utils)
reload(encoders)

reload(pacha_sketch)

from lib.sketches import BloomFilter, CountMinSketch, H3HashFunctions, HashFunctionFamily,\
      CountMinSketchHadamard, CountMinSketchLocalHashing, deterministic_hash, simple_deterministic_hash, \
      fast_hash_xx
from lib.visualization_utils import plot_boxplot, plot_relative_error, plot_boxplot_p_vs_o, \
        plot_relative_accuracy_p_vs_o, bar_plot_p_vs_o, plot_selectivities, plot_predicates, \
        bar_plot, plot_violinplot_p_vs_o, error_bar_plot_p_vs_o, plot_scatter, plot_violinplot, \
        bar_plot_no_outliers, legend_bar_plot_p_vs_o, plot_boxplot_p_vs_s, plot_lineplot_p_vs_o, \
        plot_boxplot_heuristics

from lib.encoders import minimal_b_adic_cover, minimal_spatial_b_adic_cover, BAdicCube, BAdicRange, \
      minimal_b_adic_cover_array, downgrade_b_adic_range_indices
from lib.pacha_sketch import PachaSketch, ADTree, BFParameters, CMParameters, \
      cartesian_product, get_n_updates, MaterializedCombinations, get_n_updates_customized

from lib.ploting import set_style, plot_ylabel, plot_legend

from lib import baselines
reload(baselines)

from lib.baselines import CentralDPServer, LDPServer, LDPEncoderGRR, filter_df, query_df, \
      infer_domains_and_ranges, translate_query_region, evaluate_queries, check_accruracy, \
      evaluate_queries_baselines, evaluate_equivalent_pacha_sketches, compute_relative_entropy

set_style(font_scale=0.8)

# %% [markdown]
# # Utils

# %%
base_results_path = '../results/experiments_results/'

# VLDB
# w = 7
# PhD thesis
# w = 6.16
# ICDE
w = 7.16
w_1_6 = w / 6
w_1_4 = w * 0.25
w_1_3 = w / 3
w_1_2 = w / 2

h = 1.2
# h = 1
h2 = h+0.1

s_1_4 = (w_1_4, h)
s_2_4 = (w_1_4*2, h)
# s_1_4_po = (w_1_4, h2)

s_1_3 = (w_1_3, h)

s_1_6 = (w_1_6, h)

s_2_3 = (w_1_3*2, h)
s_1_2 = (w_1_2, h)

to_display = (w_1_3*2, h*2)

def remove_ourliers(result_df):
    q1 = result_df['normalized_error'].quantile(0.25)
    q3 = result_df['normalized_error'].quantile(0.75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr

    result_df_no_outliers = result_df[(result_df['normalized_error'] >= lower_bound) & (result_df['normalized_error'] <= upper_bound)].copy()
    return result_df_no_outliers

# %% [markdown]
# # Different Aggregates

# %%
results_files = [
    f'{base_results_path}pacha/tpch/tpch_random.csv',
   f'{base_results_path}aggregates/tpch_sums.csv',
    f'{base_results_path}aggregates/tpch_avgs.csv',
    f'{base_results_path}aggregates/tpch_mins.csv',
    f'{base_results_path}aggregates/tpch_maxs.csv'
]

# labels = ['count', 'sum', 'avg', 'min', 'max']
labels = ['count', 'sum', 'avg', 'min', 'max']

results = []
relative_entropies = []
box_data = []

for i, file in enumerate(results_files):
    result_df = pd.read_csv(file)
    result_df['approach'] = 'cnt' if labels[i] == 'count' else labels[i] 
    box_data.append(result_df['relative_error'].values)
    results.append(result_df)
    re = compute_relative_entropy(result_df, col='true_'+labels[i]+'s')
    relative_entropies.append(re)
    print(f'Relative Entropy for {labels[i]}: {re}')

palette = {
    'cnt': 'tab:blue',
    'sum': 'tab:blue',
    'avg': 'tab:blue',
    'min': 'tab:blue',
    'max': 'tab:blue'
}
combined_df = pd.concat(results, ignore_index=True)
bar_values = relative_entropies
# Out:
# Relative Entropy for count: 0.014172697707073882
# Relative Entropy for sum: 0.011790748416959186
# Relative Entropy for avg: 0.001749740733461199
# Relative Entropy for min: 8.441343652050018e-06
# Relative Entropy for max: 0.03606935117551754

# %%
handles = []
handles.append(Patch(facecolor='tab:blue', edgecolor='black', alpha=0.6, linewidth=1.0, label='rel. error'))
handles.append(Patch(facecolor='tab:red', edgecolor='black', alpha=0.6, linewidth=1.0, label='rel. entropy'))

labels_ = ['rel. error', 'rel. entropy']
plot_legend(path='../figures/aggregates/labels_aggregates.pdf', handles=handles, labels=labels_, ncol=2)

# %%
# fig, ax1 = plt.subplots(figsize=s_1_4)
fig, ax1 = plt.subplots(figsize=(w*0.3, h-0.1))

# --- Boxplots ---
sns.boxplot(
    data=combined_df,
    x='approach',
    y='relative_error',
    hue='approach',
    palette=palette,
    ax=ax1,
    showfliers=False
)

for patch in ax1.patches:
    patch.set_facecolor(patch.get_facecolor())
    patch.set_linewidth(1.0)
    patch.set_alpha(0.8)

ax1.set_ylabel("rel. error")

# --- Secondary axis ---
ax2 = ax1.twinx()

# Get categorical positions from seaborn
# x_positions = np.arange(len(labels))

rel_entropy_color = 'tab:red'

for i, value in enumerate(relative_entropies):
            x_pos = i  # box positions are integers in seaborn
            ax2.scatter(x_pos, value, color=rel_entropy_color, zorder=5, marker='x', alpha=0.8)
        
ax1.set_xlabel('aggregate function')
# ax1.set_xlabel('')


# ax2.set_ylabel(r"relative entropy (x$e^{-2}$)", color=rel_entropy_color)
ax2.set_ylabel("rel. entropy", color=rel_entropy_color)
ax2.tick_params(axis='y', labelcolor=rel_entropy_color)
ax2.spines['right'].set_color(rel_entropy_color)
ax2.tick_params(axis='y', colors=rel_entropy_color)

ax2.set_ylim(0, 0.045)
# ax2.set_yticks([1e-2, 2e-2, 3e-2, 4e-2])
# ax2.set_yticklabels([1, 2,3, 4])

ax1.grid(True, axis='y', linestyle='--')

# Align ticks between box + bar
# ax1.set_xticks(x_positions + 0.20)
# labels = ['count', 'sum', 'avg', 'min', 'max']
# ax1.set_xticklabels(labels, rotation=45)

labels = ['cnt', 'sum', 'avg', 'min', 'max']

# labels = ['c', 's', 'a', 'n', 'x']
# ax1.set_xticklabels(labels, rotation=-40)

plt.tight_layout()
fig.savefig('../figures/aggregates/aggregates.pdf', bbox_inches='tight', pad_inches=0.05)

plt.show()

# %% [markdown]
# # Comparison to State-of-the-art: Different Datasets

# %%
dataset_names = ['tpch', 'retail', 'census', 'bank']
dataset_labels = ['Ltm', 'OR', 'US', 'BM'] 
# dataset_labels = ['l', 'r', 'c', 'b'] 
datasets_palette = {
    'tpch' : 'tab:blue',
    'retail' : 'tab:orange',
    'census' : 'tab:purple',
    'bank' : 'tab:green'
}

# %% [markdown]
# ## Normalized Error

# %%
custom_palette = {}
approaches = ['pacha', 'omni'] 
results = []
for appoach in approaches:
    for dataset_name, label in zip(dataset_names, dataset_labels):
        result_df = pd.read_csv(f'{base_results_path}{appoach}/{dataset_name}/{dataset_name}_random.csv')
        result_df['approach'] = f'{appoach[0].upper()}-' + label
        result_df['dataset'] = label
        result_df['method'] = appoach[0].upper()
        # print(f"Dataset: {dataset_name}, median normalized error: {result_df['normalized_error'].median()}")
        custom_palette[f'{appoach[0].upper()}-' + label] = datasets_palette[dataset_name]
        results.append(result_df)
results = [results[i] for i in [0, 4, 1, 5, 2, 6, 3, 7]]

rel_entropies = []
rel_entropies_no_outliers = []
for result_df in results:
    rel_entropies.append(compute_relative_entropy(result_df))
    rel_entropies_no_outliers.append(compute_relative_entropy(remove_ourliers(result_df)))

combined_df = pd.concat(results, ignore_index=True)
labels = combined_df['approach'].unique()

# %%
fig = plot_boxplot_p_vs_o(results, x_label='dataset',log_scale=True, relative_entropies=rel_entropies, lower_move=0.3, figsize=(w*0.4, h), palette=custom_palette)
fig.savefig('../figures/pacha_vs_omni/normalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
def legend_bar_plot_p_vs_o(
    results : list,
    labels: list[str],
    y_label='throughput (updt./s)',
    lower_move=0.1, 
    figsize: tuple[int, int] = (5, 3),
    palette=None
):
    fig, ax = plt.subplots(figsize=figsize)
    ax.grid(True, axis='y', linestyle='--')

    labels_ = [lab.replace('P-', 'PS-').replace('O-', 'OS-') for lab in labels]

    ax.bar(
        labels_,
        results,
        color=[palette[label] for label in labels],
        capsize=5,
        edgecolor='black',
        width=0.8
    )

    legend_elements = []

    for patch, label in zip(ax.patches, labels_):
        if label.startswith('Ps'):
            patch.set_facecolor(patch.get_facecolor())  # keep color
            patch.set_linewidth(1.0)
            patch.set_hatch('')
            patch.set_alpha(0.6)
        elif label.startswith('P'):
            patch.set_facecolor(patch.get_facecolor())  # keep color
            patch.set_linewidth(1.0)
            patch.set_hatch('')
            patch.set_alpha(0.8)
            legend_elements.append(Patch(facecolor=patch.get_facecolor(), edgecolor='black', hatch='', label=label))
        else:  # baseline 'o-'
            legend_elements.append(Patch(facecolor='white', edgecolor=patch.get_facecolor(), linewidth=1.5, hatch='////', label=label))
            patch.set_edgecolor(patch.get_facecolor())
            patch.set_facecolor('white')
            patch.set_linewidth(1.5)
            # patch.set_hatch('///')
            patch.set_hatch('XXXX')


    fig.subplots_adjust(bottom=0.18)
    ax.set_ylabel(y_label)
    ax.legend(handles=legend_elements)

    # handles, labels = plt.gca().get_legend_handles_labels()
    plt.tight_layout()
    return fig, legend_elements, labels_

# %%
fig, handles, labels_ = legend_bar_plot_p_vs_o(rel_entropies, labels, lower_move=0.2, y_label='relative entropy', figsize=s_1_4, palette=custom_palette)

# %%
# handles, labels_ = ax.get_legend_handles_labels()
plot_legend(path='../figures/pacha_vs_omni/labels_datasets.pdf', handles=handles, labels=labels_, ncol=4)

# %% [markdown]
# ## Query Efficiency

# %%
custom_palette = {}
for appoach in approaches:
    for dataset_name, label in zip(dataset_names, dataset_labels):
        custom_palette[f'{appoach[0].upper()}-' + label] = datasets_palette[dataset_name]
# fig = bar_plot_p_vs_o(results, labels, figsize=to_display, palette=custom_palette)
# fig = plot_violinplot_p_vs_o(results,log_scale=True, col_y='runtime', y_label='Runtime (ms)', figsize=to_display, palette=custom_palette)
# fig = error_bar_plot_p_vs_o(results, lower_move=0.2, col_y='runtime', y_label='runtime (ms)', figsize=(w_1_4,h+0.1), palette=custom_palette)
fig = error_bar_plot_p_vs_o(results, x_label='dataset',lower_move=0.2, col_y='runtime', y_label='runtime (ms)', figsize=(w*0.3,h-0.07), palette=custom_palette)

fig.savefig('../figures/pacha_vs_omni/query_efficiency.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# ## Update Efficiency

# %%
custom_palette = {}
results = []
labels = []
approaches = ['P', 'Ps', 'O']
for dataset_name, label in zip(dataset_names, dataset_labels):
    result_df = pd.read_csv(f'{base_results_path}update_efficiency/{dataset_name}_throughputs.csv')
    results.extend(result_df.max().values)
    for appoach in approaches:
        appoach_label = f'{appoach}-{label}'
        custom_palette[appoach_label] = datasets_palette[dataset_name]
        labels.append(appoach_label)

# %%
fig, ax = bar_plot_p_vs_o(results, labels, x_label='dataset', y_label=r"x$10^{3}$ tuples/s", lower_move=0.3, figsize=(w*0.4,h), palette=custom_palette)
fig.savefig('../figures/pacha_vs_omni/update_efficiency.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
# handles, labels = ax.get_legend_handles_labels()
plot_legend(path='../figures/pacha_vs_omni/update_labels.pdf', handles=ax.patches, labels=labels, ncol=4)

# %%
handles = ax.patches
handles_ordered = [handles[i] for i in [0, 6, 1, 7, 2, 8, 3, 9, 4, 10, 5, 11]]
labels_reordered = [labels[i] for i in [0, 6, 1, 7, 2, 8, 3, 9, 4, 10, 5, 11]]
plot_legend(path='../figures/pacha_vs_omni/update_labels2.pdf', handles=handles_ordered, labels=labels_reordered, ncol=6)

# %%
selected_handles = [copy.copy(handles[i]) for i in [0, 1, 2]]
selected_handles[0].set_facecolor('grey')
selected_handles[1].set_facecolor('grey')
selected_handles[1].set_hatch('....')
selected_handles[2].set_edgecolor('grey')

labels_selected = ['Pacha Sketch', 'Pacha Sketch parallel', 'Omni Sketch']

plot_legend(path='../figures/pacha_vs_omni/update_labels3.pdf', handles=selected_handles, labels=labels_selected, ncol=3)

# %%
selected_handles = [copy.copy(handles[i]) for i in [0, 2]]
selected_handles[0].set_facecolor('grey')
selected_handles[1].set_edgecolor('grey')

labels_selected = ['Pacha Sketch', 'Omni Sketch']

plot_legend(path='../figures/pacha_vs_omni/labels_datasets2.pdf', handles=selected_handles, labels=labels_selected, ncol=2)

# %% [markdown]
# ## Error Analysis

# %%
results = []
appoach = 'P'

markers = ['o', 'X', '^', 'D']
custom_palette = {}
for dataset_name, label in zip(dataset_names, dataset_labels):
    result_df = pd.read_csv(f'{base_results_path}pacha/{dataset_name}/{dataset_name}_random.csv')
    result_df['approach'] = f'{appoach[0].upper()}-' + label
    custom_palette[f'{appoach[0].upper()}-' + label] = datasets_palette[dataset_name]
    # print(f"Dataset: {dataset_name}, median normalized error: {result_df['normalized_error'].median()}")
    results.append(result_df)

# %%
fig, ax = plot_scatter(results=results, figsize=(w*0.3, h),
                   y_label="norm. error",
                   x_max=5000, 
                   step=2000,
                   palette=custom_palette,
                   markers=markers)
fig.savefig('../figures/pacha_vs_omni/error_analysis.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
handles, labels = ax.get_legend_handles_labels()
labels = [lab.replace('P-', '') for lab in labels]

plot_legend(path='../figures/pacha_vs_omni/analysis_labels.pdf', handles=handles, labels=labels, ncol=4)

# %%
fig, ax = plot_scatter(results=results, 
                   y_col='runtime',
                   x_col='total_sketch_queries',
                   x_label='nr. internal queries',
                   y_label='runtime (ms)',
                   x_max=200_000,
                   step=80_000,
                   figsize=(w*0.3, h), palette=custom_palette,
                   markers=markers)
fig.savefig('../figures/pacha_vs_omni/runtime_analysis.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# # Different Queries

# %%
fig = plot_selectivities('tpch', figsize=s_1_4)

# fig = plot_boxplot_p_vs_o(results,log_scale=True, lower_move=0.20, figsize=s_1_4, palette=custom_palette)
# fig = plot_violinplot_p_vs_o(results, lower_move=0.2, log_scale=True, figsize=s_1_3, palette=custom_palette)

fig.savefig('../figures/pacha_vs_omni/selectivities_tpch.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig = plot_predicates('tpch', 'categorical', figsize=s_1_4)
fig.savefig('../figures/pacha_vs_omni/categorical_tpch.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig = plot_predicates('tpch', 'numerical', figsize=s_1_4)
fig.savefig('../figures/pacha_vs_omni/numerical_tpch.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig = plot_predicates('tpch', 'mixed', figsize=s_1_4)
fig.savefig('../figures/pacha_vs_omni/mixed_tpch.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
handles = [
    Line2D(
        [0], [0],
        color=datasets_palette['tpch'],
        linestyle='-',
        linewidth=2,
        label='Pacha Sketch'
    ),
    Line2D(
        [0], [0],
        color=datasets_palette['tpch'],
        linestyle='--',
        linewidth=2,
        label='Omni Sketch'
    )
]
labels = [h.get_label() for h in handles]
plot_legend(path='../figures/pacha_vs_omni/labels_workloads.pdf', handles=handles, labels=labels, ncol=2)

# %% [markdown]
# # Scalability

# %%
scale_factors = ['187_k', '750_k', '3_M', '12_M', '48_M']
n_elements = ['0.2', '0.8', '3', '12', '48']
custom_palette = {}

results = []
for sf, n in zip(scale_factors, n_elements):
    result_df = pd.read_csv(f"{base_results_path}scalability/tpchrandom_scale_{sf}.csv")
    custom_palette[n] = datasets_palette['tpch']
    # result_df = result_df[result_df['b_adic_cubes'] < 50_000]
    result_df['approach'] = n
    results.append(result_df)

rel_entropies = []
rel_entropies_no_outliers = []
for result_df in results:
    rel_entropies.append(compute_relative_entropy(result_df))
    rel_entropies_no_outliers.append(compute_relative_entropy(remove_ourliers(result_df)))

# %%
fig = plot_boxplot(results, target=[0.0001]*len(results), relative_entropies=rel_entropies, rel_entropies_no_outliers=rel_entropies_no_outliers, scale_x_ticks=0.8, log_scale=True, x_label='~ nr. rows (in millions)', figsize=(w*0.25, h), palette=custom_palette)
# fig = plot_violinplot(results, target=[0.0001]*len(results), log_scale=True, x_label='~ nr. rows', figsize=s_1_3, palette=custom_palette)
fig.savefig('../figures/scalability/normalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
handles = [
    Line2D(
        [0], [0],
        color='orange',
        linestyle='--',
        linewidth=2,
        label='Target error (median)'
    ),
    Line2D(
        [0], [0],
        color='tab:red',
        linestyle='-',
        linewidth=2,
        label='Relative entropy'
    ),
    Line2D(
        [0], [0],
        color='tab:red',
        linestyle='--',
        linewidth=2,
        label='Relative entropy (no outliers)'
    )
]
labels = [h.get_label() for h in handles]

# %%
plot_legend(path='../figures/scalability/labels.pdf', handles=handles, labels=labels, ncol=3)

# %% [markdown]
# # Error Guarantees

# %%
results_files = [
    "tpchrandom_eps_0.0004_p_0.04.csv",
    "tpchrandom_eps_0.0002_p_0.02.csv",
    "tpchrandom_eps_0.0001_p_0.01.csv",
    "tpchrandom_eps_0.00005_p_0.005.csv",
    "tpchrandom_eps_0.000025_p_0.0025.csv"
]
rel_epsilons = 2**np.arange(4,-1,-1) * 0.000025

labels = np.arange(1, len(results_files) +1)
custom_palette = {}

results = []
for label, file in zip(labels, results_files):
    result_df = pd.read_csv(f"{base_results_path}guarantees/{file}")
    custom_palette[label] = datasets_palette['tpch']
    # result_df = result_df[result_df['b_adic_cubes'] < 50_000]
    result_df['approach'] = label
    results.append(result_df)

rel_entropies = []
rel_entropies_no_outliers = []
for result_df in results:
    rel_entropies.append(compute_relative_entropy(result_df))
    rel_entropies_no_outliers.append(compute_relative_entropy(remove_ourliers(result_df)))

# %%
# fig = plot_violinplot(results, target=rel_epsilons, log_scale=True, x_label='configuration', figsize=to_display, palette=custom_palette)
fig = plot_boxplot(results, target=rel_epsilons, relative_entropies=rel_entropies, log_scale=True, x_label='configuration', figsize=(w*0.25, h), palette=custom_palette) 
fig.savefig('../figures/guarantees/normalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# # Pacha Parameters

# %% [markdown]
# ## Custom Bases for the B-Adic Space Cover

# %%
results_files = [
    "bases/tpchrandom_bases_2_2_2_2_2.csv",
    "bases/tpchrandom_bases_5_5_5_5_5.csv",
    "bases/tpchrandom_bases_5_5_5_10_2.csv",
    "bases/tpchrandom_bases_10_10_10_10_10.csv"
]


labels = ['2', '5', 'cust.', '10']
custom_palette = {}

results = []
for label, file in zip(labels, results_files):
    result_df = pd.read_csv(f"{base_results_path}parameters/{file}")
    custom_palette[label] = datasets_palette['tpch']
    result_df['approach'] = label
    results.append(result_df)

rel_entropies = []
rel_entropies_no_outliers = []
for result_df in results:
    rel_entropies.append(compute_relative_entropy(result_df))
    rel_entropies_no_outliers.append(compute_relative_entropy(remove_ourliers(result_df)))

# %%
fig = plot_boxplot(results, log_scale=True, relative_entropies=rel_entropies, x_label='configuration', figsize=s_1_4, palette=custom_palette)
fig.savefig('../figures/bases/normalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# ## Different Levels

# %%
results_files = [
    "levels/tpchrandom_levels_3.csv",
    "levels/tpchrandom_levels_5.csv",
    "levels/tpchrandom_levels_7.csv",
    "levels/tpchrandom_levels_9.csv"
]


labels = [3, 5, 7, 9]
custom_palette = {}

results = []
for label, file in zip(labels, results_files):
    result_df = pd.read_csv(f"{base_results_path}parameters/{file}")
    custom_palette[label] = datasets_palette['tpch']
    result_df['approach'] = label
    results.append(result_df)

rel_entropies = []
rel_entropies_no_outliers = []
for result_df in results:
    rel_entropies.append(compute_relative_entropy(result_df))
    rel_entropies_no_outliers.append(compute_relative_entropy(remove_ourliers(result_df)))

# %%
fig = plot_boxplot(results, log_scale=True, relative_entropies=rel_entropies, x_label='nr. levels', figsize=s_1_4, palette=custom_palette)
fig.savefig('../figures/levels/normalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# # Streaming with Fix Size

# %%
custom_palette = {
    64 : 'tab:brown',
    128 : 'tab:purple',
    256 : 'tab:pink',
    512 : 'tab:green',
    1024 : 'tab:orange'
}

mem_budgets = [64, 128, 256, 512, 1024]  # in MB

limits = [30]*5
# max_m = 5
# limits = [3, 3, 5, max_m, max_m]

results_base_dir = "../results/experiments_results/memory_budget/"

approaches = ["pacha", "omni"]
approach_labels = {
    "pacha": "PS",
    "omni": "OS"
}

column_to_use = 'normalized_error'
# column_to_use = 'relative_error'

results_medians = {}
results_25 = {}
results_75 = {}
results_rel_entropies = {}
not_valids = {}
for i, mem_budget in enumerate(mem_budgets):
    for approach in approaches:
        medians = []
        quantiles_25 = []
        quantiles_75 = []
        rel_entropies = []
        for n in np.arange(1, limits[i]+1):
            results_file = f"tpchmemory_{mem_budget}_MB_{n}.csv"
            path_to_estimates = f"{results_base_dir}{approach}/{results_file}"                           
            try: 
                result_df = pd.read_csv(path_to_estimates)
            except FileNotFoundError:
                # print(f"File not found for mem budget: {mem_budget}, n: {n}")
                print(path_to_estimates)
                continue
            # result_df = result_df[result_df['b_adic_cubes'] < 50_000]
            if result_df.empty:
                print('No valid results for mem budget:', mem_budget, 'and n:', n)
                break
            medians.append(result_df[column_to_use].median())
            quantiles_25.append(result_df[column_to_use].quantile(0.25))
            quantiles_75.append(result_df[column_to_use].quantile(0.75))
            rel_entropies.append(compute_relative_entropy(result_df))

        label = f"{approach_labels[approach]}-{mem_budget}"
        results_medians[label] = np.asarray(medians)
        results_25[label] = np.asarray(quantiles_25)
        results_75[label] = np.asarray(quantiles_75)
        results_rel_entropies[label] = np.asarray(rel_entropies)
# Out:
# ../results/experiments_results/memory_budget/omni/tpchmemory_1024_MB_29.csv
# ../results/experiments_results/memory_budget/omni/tpchmemory_1024_MB_30.csv

# %%
def plot_variable_length_error_lines(
    results_medians,
    custom_palette,
    results_25=None,
    results_75=None,
    y_label='norm. error',
    markers={
        'PS': 'o',
        'OS': 'x',
    },
    linestyles={
        'PS': '-',
        'OS': '--',
        'Baseline': '-'
    },
    plot_error_areas=False,
    figsize=(6, 4),
    min_mem=None, 
    log_scale=False, 
    index_range=None  # e.g., (1, 4)
):
    # Prepare the figure
    fig, ax = plt.subplots(figsize=figsize, dpi=200)
    # plt.plot(times_pd_1024, label='Pandas', color='red')
    for method in results_medians:
        # extract number after '-' (e.g. 'PS-64' -> 64)
        if method == 'Baseline':
            approach = 'Baseline'
            mem_num = 'Baseline'
        else:
            approach = method.rsplit('-', 1)[0]
            mem_num = int(method.rsplit('-', 1)[1])
        if min_mem is not None and mem_num < min_mem:
            continue
        y_median = results_medians[method]

        # Compute range
        start, end = index_range if index_range else (0, len(y_median))
        x = np.arange(1, len(y_median)+1, dtype=int)[start:end]

        # ax.plot(x, y_median[start:end], marker=markers[approach], label={method}, color=custom_palette[mem_num])
        ax.plot(x, y_median[start:end], linestyle=linestyles[approach], label={method}, color=custom_palette[mem_num])
        if plot_error_areas:
            y25 = results_25[method]
            y75 = results_75[method]
            ax.fill_between(x, y25[start:end], y75[start:end], color=custom_palette[mem_num], alpha=0.2)

    if log_scale:
        ax.set_yscale('log')
    # if index_range:
    #     ax.set_xticklabels(np.arange(index_range[0]+1, index_range[1]+2, (index_range[1]-index_range[0])//5))
    # else:
    #     n_points = len(y_median)
    #     ax.set_xticklabels(np.linspace(1, n_points, 10, dtype=int))
    ax.set_xlabel('nr. tuples xe5')
    ax.set_ylabel(y_label)
    ax.grid(True, linestyle='--', alpha=0.5)
    # handles, labels = plt.gca().get_legend_handles_labels()
    # plt.legend()
    plt.tight_layout()
    # plt.show()

    return fig, ax

# %%
results_medians_pacha = {k: v for k, v in results_medians.items() if 'PS' in k}
results_medians_omni = {k: v for k, v in results_medians.items() if 'OS' in k}

results_rel_entropies_pacha = {k: v for k, v in results_rel_entropies.items() if 'PS' in k}
results_rel_entropies_omni = {k: v for k, v in results_rel_entropies.items() if 'OS' in k}

# %%
fig, _ = plot_variable_length_error_lines(results_rel_entropies_pacha, custom_palette, figsize=s_1_4, y_label='rel. entropy', index_range=(0, 30))
fig.savefig('../figures/mem_budget/rel_entropies.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig, ax = plot_variable_length_error_lines(results_medians, custom_palette, figsize=s_1_4, log_scale=True, index_range=(0, 30))
fig.savefig('../figures/mem_budget/pacha_vs_omni.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
handles, labels = ax.get_legend_handles_labels()
labels = [lab+' MB' for lab in labels]
handles, labels
plot_legend(path='../figures/mem_budget/labels.pdf', handles=handles, labels=labels, ncol=5)

# %% [markdown]
# # Comparison to Priority Sampling

# %%
base_results_path = '../results/experiments_results/'

custom_palette = {}

results_files = [
    f'{base_results_path}pacha/tpch/tpch_random.csv',
    f"{base_results_path}sample/tpch/tpch_sample_count.csv",
    f'{base_results_path}aggregates/tpch_sums.csv',
    f'{base_results_path}sample/tpch/tpch_sample_sum.csv'
]

labels = ['count-PS', 'count-S', 'sum-PS', 'sum-S']

results = []
rel_entropies = []

for i, file in enumerate(results_files):
    result_df = pd.read_csv(file)
    result_df['approach'] = labels[i]
    result_df['aggregate'] = labels[i].split('-')[0]
    result_df['method'] = labels[i].split('-')[1]
    custom_palette[labels[i]] = 'tab:blue' if labels[i].endswith('PS') else 'tab:olive'
    # custom_palette[labels[i]] = 'tab:blue' if labels[i].endswith('PS') else 'tab:orange'
    if labels[i].startswith('count'):
        rel_entropies.append(compute_relative_entropy(result_df))
    else:
        rel_entropies.append(compute_relative_entropy(result_df, col='true_sums'))
    results.append(result_df)

# %%
fig = plot_boxplot_p_vs_s(results, 
                          log_scale=True, 
                          col_y='normalized_error', 
                          y_label="norm. error", 
                          x_label='aggregate function',
                          lower_move=0.2, 
                          figsize=s_1_4, 
                          palette=custom_palette,
                          plot_sub_title=False)
fig.savefig('../figures/pacha_vs_sampling/normalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
labels = ['Pacha Sketch', 'Sampling']
custom_palette = {
    'Pacha Sketch' : 'tab:blue',
    'Sampling' : 'tab:olive'
}
fig, handles, labels_ = legend_bar_plot_p_vs_o([0, 0], labels, lower_move=0.2, y_label='relative entropy', figsize=s_1_4, palette=custom_palette)

# %%
labels = ['Pacha Sketch', 'Priority Sampling']
handles, labels
plot_legend(path='../figures/pacha_vs_sampling/labels.pdf', handles=handles, labels=labels, ncol=2)

# %%
base_results_path = '../results/experiments_results/'
dataset_name = 'tpch'
results = []
selectivities = np.array([0.01, 0.04, 0.16, 0.64])

for sel in selectivities:
    result_df = pd.read_csv(f"{base_results_path}pacha/{dataset_name}/selectivities/{dataset_name}_sum_sel_{sel}.csv")
    result_df['approach'] = 'P-'+str(int(sel*100))
    results.append(result_df)

    result_df = pd.read_csv(f"{base_results_path}sample/selectivities/tpch_sample_sum_sel_{sel}.csv")
    result_df['approach'] = 'S-'+str(int(sel*100))
    results.append(result_df)

combined_df = pd.concat(results, ignore_index=True)
labels = combined_df['approach'].unique()

custom_palette = {"pacha" : "tab:blue", "omni" : "tab:olive"}

# %%
fig = plot_lineplot_p_vs_o(results, x_label='selectivity (\%)', col_y='relative_error', y_label='rel. error', figsize=s_1_4, log_scale=False, palette=custom_palette)
fig.savefig('../figures/pacha_vs_sampling/selectivities.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\%'
# <>:1: SyntaxWarning: invalid escape sequence '\%'
# /tmp/ipykernel_90527/3858694165.py:1: SyntaxWarning: invalid escape sequence '\%'
#   fig = plot_lineplot_p_vs_o(results, x_label='selectivity (\%)', col_y='relative_error', y_label='rel. error', figsize=s_1_4, log_scale=False, palette=custom_palette)

# %% [markdown]
# # AD Tree Ordering

# %% [markdown]
# ## TPCH

# %%
base_results_path = '../results/experiments_results/'

custom_palette = {}

results_files = [
    f'{base_results_path}adTree/pacha_ad_tree_ordering_skewed.csv',
    f"{base_results_path}adTree/pacha_ad_tree_ordering_uniform.csv",
    f'{base_results_path}adTree/pacha_default_ad_tree_skewed.csv',
    f'{base_results_path}adTree/pacha_default_ad_tree_uniform.csv'
]

labels = ['w-cust.', 'u-cust.', 'w-def.',  'u-def.']

results = []
rel_entropies = []

for i, file in enumerate(results_files):
    result_df = pd.read_csv(file)
    result_df['approach'] = labels[i]
    custom_palette[labels[i]] = 'tab:blue' 
    # custom_palette[labels[i]] = 'tab:blue' if labels[i].endswith('PS') else 'tab:orange'
    rel_entropies.append(compute_relative_entropy(result_df))
    results.append(result_df)

# %%
fig, ax = plot_boxplot_heuristics(results, 
                              log_scale=True, 
                              relative_entropies=rel_entropies, 
                              figsize=(w*0.29, h), 
                              palette=custom_palette,
                              x_label='ordering')

fig.savefig('../figures/adTree/tpch_nomalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig, ax1 = plot_boxplot_heuristics(results, 
                                  col_y='runtime',
                                  y_label='runtime (ms)',
                              log_scale=True, 
                              figsize=(w*0.21, h), 
                              palette=custom_palette,
                              x_label='ordering')

fig.savefig('../figures/adTree/tpch_runtime.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# ## US Census

# %%
base_results_path = '../results/experiments_results/'

custom_palette = {}

results_files = [
    f'{base_results_path}adTree/pacha_ad_tree_ordering_census_skewed.csv',
    f"{base_results_path}adTree/pacha_ad_tree_ordering_census_uniform.csv",
    f'{base_results_path}adTree/pacha_default_ad_tree_census_skewed.csv',
    f'{base_results_path}adTree/pacha_default_ad_tree_census_uniform.csv'
]

labels = ['w-cust.', 'u-cust.', 'w-def.',  'u-def.']

results = []
rel_entropies = []

for i, file in enumerate(results_files):
    result_df = pd.read_csv(file)
    result_df['approach'] = labels[i]
    custom_palette[labels[i]] = 'tab:purple' 
    # custom_palette[labels[i]] = 'tab:blue' if labels[i].endswith('PS') else 'tab:orange'
    rel_entropies.append(compute_relative_entropy(result_df))
    results.append(result_df)

# %%
fig, ax = plot_boxplot_heuristics(results, 
                              log_scale=True, 
                              relative_entropies=rel_entropies, 
                              figsize=(w*0.29, h), 
                              palette=custom_palette,
                              x_label='ordering')

fig.savefig('../figures/adTree/census_nomalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig, ax2 = plot_boxplot_heuristics(results, 
                                  col_y='runtime',
                                  y_label='runtime (ms)',
                              log_scale=True, 
                              figsize=(w*0.21, h), 
                              palette=custom_palette,
                              x_label='ordering')

fig.savefig('../figures/adTree/census_runtime.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
set_style(font_scale=0.9)

# %% [markdown]
# ## Legend

# %%
handles = [ax1.patches[0], ax1.patches[1], ax2.patches[0], ax2.patches[1]]
labels = ['Weighted - Ltm', 'Uniform - Ltm', 'Weighted - US', 'Uniform - US']
plot_legend(path='../figures/adTree/labels.pdf', handles=handles, labels=labels, ncol=4)

# %% [markdown]
# # Maximum Number of B-Adic Cubes

# %%
base_results_path = '../results/experiments_results/maxNCubes/'

custom_palette = {}

# max_n_cubes = [100, 1000, 10_000, 100_000, 1_000_000, 10_000_000, 100_000_000]
# labels = ['100', '1k', '10k', '100k', '1M', '10M', '100M']

max_n_cubes = [100, 10_000, 1_000_000, 100_000_000]
labels = ['100', '10k', '1M', '100M']

results = []
rel_entropies = []

for i, n_cubes in enumerate(max_n_cubes):
    file = f"{base_results_path}tpchrandom_maxNCubes_{n_cubes}.csv"
    result_df = pd.read_csv(file)
    result_df['approach'] = labels[i]
    custom_palette[labels[i]] = 'tab:blue' 
    # custom_palette[labels[i]] = 'tab:blue' if labels[i].endswith('PS') else 'tab:orange'
    rel_entropies.append(compute_relative_entropy(result_df))
    results.append(result_df)

# %%
fig, ax = plot_boxplot_heuristics(results, 
                            #   log_scale=True, 
                              relative_entropies=rel_entropies, 
                              figsize=(w*0.29, h), 
                              palette=custom_palette,
                              label_prefix=None,
                              x_label='max. nr. cubes')

fig.savefig('../figures/nCubes/nomalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig, ax1 = plot_boxplot_heuristics(results, 
                                  col_y='runtime',
                                  y_label='runtime (ms)',
                            #   log_scale=True, 
                              figsize=(w*0.21, h), 
                              palette=custom_palette,
                              label_prefix=None,
                              x_label='max. nr. cubes')
fig.savefig('../figures/nCubes/runtime.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %% [markdown]
# # Projected Subspaces

# %%
base_results_path = '../results/experiments_results/subspaces/'
# base_results_path = '../results/experiments_results/subspaces_copy/'

results_files = [
    f'{base_results_path}mat_subspaces_none_workload.csv',
    f'{base_results_path}mat_subspaces_none_uniform.csv',
    f'{base_results_path}mat_subspaces_single_workload.csv',
    f"{base_results_path}mat_subspaces_single_uniform.csv",
    f'{base_results_path}mat_subspaces_default_workload.csv',
    f'{base_results_path}mat_subspaces_default_uniform.csv',
    f'{base_results_path}mat_subspaces_custom_workload.csv',
    f'{base_results_path}mat_subspaces_custom_uniform.csv',
    f'{base_results_path}mat_subspaces_all_workload.csv',
    f'{base_results_path}mat_subspaces_all_uniform.csv'
]

labels = [
    'w-none', 'u-none',
    'w-single', 'u-single', 'w-pairs', 'u-pairs', 'w-custom', 'u-custom', 'w-all', 'u-all'
]

custom_palette = {}

results = []
rel_entropies = []
for i, file in enumerate(results_files):
    result_df = pd.read_csv(file)
    result_df['approach'] = labels[i]
    custom_palette[labels[i]] = 'tab:blue'
    # custom_palette[labels[i]] = 'tab:blue' if labels[i].endswith('u') else 'tab:orange'
    rel_entropies.append(compute_relative_entropy(result_df))
    results.append(result_df)

# %%
fig, ax = plot_boxplot_heuristics(results, 
                              log_scale=True, 
                              relative_entropies=rel_entropies, 
                              figsize=s_1_2, 
                              palette=custom_palette,
                              x_label='projected subspaces')

fig.savefig('../figures/subspaces/nomalized_error.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
fig, ax1 = plot_boxplot_heuristics(results, 
                                  col_y='runtime',
                                  y_label='runtime (ms)',
                              log_scale=True, 
                              figsize=s_1_2, 
                              palette=custom_palette,
                              x_label='projected subspaces')
fig.savefig('../figures/subspaces/runtime.pdf', bbox_inches='tight', dpi=300, pad_inches=0.05)

# %%
handles = [ax1.patches[0], ax1.patches[1]]
labels = ['Weighted - Ltm', 'Uniform - Ltm']
plot_legend(path='../figures/subspaces/labels.pdf', handles=handles, labels=labels, ncol=2)
